# %% [markdown]
# <a href="https://colab.research.google.com/github/yeshwantps2008-ux/CODEALPA-/blob/main/Task1_Translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deep-translator

from deep_translator import GoogleTranslator

text = input("Enter Text: ")

translated = GoogleTranslator(
    source='en',
    target='ta'
).translate(text)

print("Translated:", translated)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.3 MB/s eta 0:00:00
# ...
# Enter Text: Vankooo
# Translated: வாங்கூ
